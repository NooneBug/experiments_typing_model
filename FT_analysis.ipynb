# %%
import pickle
from typing_model.models.BERT_models import ConcatenatedContextBERTTyper
from torch.nn import Sigmoid
import torch

# %%
path_to_base_model = 'checkpoints/BBS_figer-v0.ckpt'
base_model_aux_path = 'dataloaders/Bert_Baseline_figer_train_auxiliary_variables.pkl'
base_model_dev_loader_path = 'dataloaders/Bert_Baseline_figer_dev.pkl'

# %%
path_to_ft_model = 'checkpoints/FT_BBN_into_FIGER-v0.ckpt'
ft_model_aux_path = 'dataloaders/Bert_Baseline_figer_train_auxiliary_variables.pkl'
ft_model_dev_loader_path = 'dataloaders/Bert_Baseline_figer_dev.pkl'

# %%
path_to_frozen_model = 'checkpoints/BBS_bbn-v1.ckpt'
fro_model_aux_path = 'dataloaders/Bert_Baseline_bbn_train_auxiliary_variables.pkl'
fro_model_dev_loader_path = 'dataloaders/Bert_Baseline_bbn_dev.pkl'

# %% [markdown]
# ### Load aux variables

# %%
with open(base_model_aux_path, 'rb') as inp:
    bm_id2label, bm_label2id, bm_class_number = pickle.load(inp)

# %%
with open(ft_model_aux_path, 'rb') as inp:
    ft_id2label, ft_label2id, ft_class_number = pickle.load(inp)

# %%
with open(fro_model_aux_path, 'rb') as inp:
    fro_id2label, fro_label2id, fro_class_number = pickle.load(inp)

# %% [markdown]
# ### Load models & dataloaders

# %%
base_model = ConcatenatedContextBERTTyper.load_from_checkpoint(path_to_base_model,
                                                               id2label = bm_id2label, 
                                                               label2id = bm_label2id, 
                                                               classes = bm_class_number,
                                                              weights = None).cuda()

# %%
ft_model = ConcatenatedContextBERTTyper.load_from_checkpoint(path_to_ft_model,
                                                               id2label = ft_id2label, 
                                                               label2id = ft_label2id, 
                                                               classes = ft_class_number,
                                                              weights = None).cuda()

# %%
fro_model = ConcatenatedContextBERTTyper.load_from_checkpoint(path_to_frozen_model,
                                                               id2label = fro_id2label, 
                                                               label2id = fro_label2id, 
                                                               classes = fro_class_number,
                                                              weights = None).cuda()

# %%
with open(base_model_dev_loader_path, 'rb') as inp:
    dataloader = pickle.load(inp)

# %% [markdown]
# ## Generate Predictions

# %%
sig = Sigmoid().cuda()

# %%
mini_batch_size = 10
admit_void_prediction = False

# %%
def get_model_pred(model, id2label, mentions, contexts):
    all_preds = []
    all_labels = []
    avg_predictions = 0
    
    mentions = mentions.cuda()
    contexts = contexts.cuda()
    pred = sig(model(mentions, contexts))

    pred = pred.detach().cpu()

    mask = pred > .5
    batch_preds = []
    for i, m in enumerate(mask):
        ex_preds = []   
        pred_ids =  m.nonzero()

        if len(pred_ids) == 0:
            if admit_void_prediction:
                void_counter += 1
            else:
                pred_ids = [torch.argmax(pred[i])]
        avg_predictions += len(pred_ids)

        for p in pred_ids:
            ex_preds.append(id2label[p.item()])
        batch_preds.append(ex_preds)
    all_preds.extend(batch_preds)
    
    avg_predictions = avg_predictions/mini_batch_size
    return all_preds, avg_predictions

# %%
dt = iter(dataloader)

# %%
mention, context, label = next(dt)

# %%
i = 0

# %%
i += mini_batch_size

# %%
base_preds, base_avg_preds = get_model_pred(base_model, bm_id2label, 
                                             mention[i: i + mini_batch_size], 
                                             context[i: i + mini_batch_size])
ft_preds, ft_avg_preds = get_model_pred(ft_model, ft_id2label, 
                                       mention[i: i + mini_batch_size],
                                       context[i: i + mini_batch_size])
fro_preds, fro_avg_preds = get_model_pred(fro_model, fro_id2label, 
                                       mention[i: i + mini_batch_size],
                                       context[i: i + mini_batch_size])

# %%
mask = label == 1
batch_labels = []
for m in mask:
    ex_labels = []
    labels_ids = m.nonzero()
    for l in labels_ids:
        ex_labels.append(bm_id2label[l.item()])
    batch_labels.append(ex_labels)
batch_labels
# Out:
# [['/person/athlete', '/person'],
#  ['/person/author', '/person/artist', '/person/musician', '/person'],
#  ['/person/artist',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government_agency',
#   '/language',
#   '/title',
#   '/person'],
#  ['/art/film', '/art'],
#  ['/location'],
#  ['/person/actor', '/person'],
#  ['/language'],
#  ['/location/city', '/location'],
#  ['/location/city', '/location'],
#  ['/person/artist', '/person/musician', '/person'],
#  ['/person/athlete', '/person'],
#  ['/location/city', '/location'],
#  ['/location'],
#  ['/person/author',
#   '/person/athlete',
#   '/person/actor',
#   '/person/artist',
#   '/person'],
#  ['/organization'],
#  ['/location/country', '/location'],
#  ['/building', '/location'],
#  ['/location'],
#  ['/location/body_of_water', '/location'],
#  ['/people/ethnicity',
#   '/people',
#   '/person/artist',
#   '/location/country',
#   '/location',
#   '/person'],
#  ['/location'],
#  ['/building', '/location', '/building/sports_facility'],
#  ['/location/city', '/location'],
#  ['/organization', '/organization/sports_team'],
#  ['/person/doctor', '/title', '/person'],
#  ['/organization', '/organization/sports_team'],
#  ['/person/artist', '/person/musician', '/person'],
#  ['/living_thing'],
#  ['/music'],
#  ['/news_agency',
#   '/organization',
#   '/person/engineer',
#   '/organization/company',
#   '/person'],
#  ['/organization', '/government', '/government/political_party'],
#  ['/organization', '/person/engineer', '/organization/company', '/person'],
#  ['/person/author',
#   '/military',
#   '/organization',
#   '/government_agency',
#   '/title',
#   '/person'],
#  ['/location/city', '/location'],
#  ['/person/author', '/person/artist', '/person/musician', '/person'],
#  ['/organization'],
#  ['/person/athlete', '/person'],
#  ['/person/artist', '/location/country', '/location', '/person'],
#  ['/person/artist',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government_agency',
#   '/language',
#   '/title',
#   '/person'],
#  ['/person'],
#  ['/person/actor', '/organization', '/organization/sports_team', '/person'],
#  ['/location/city', '/location'],
#  ['/person/author', '/person'],
#  ['/living_thing'],
#  ['/location/city', '/location'],
#  ['/organization/sports_league', '/organization', '/event'],
#  ['/building', '/location', '/building/theater'],
#  ['/award'],
#  ['/location/city', '/location'],
#  ['/people/ethnicity', '/people', '/location/country', '/location'],
#  ['/location', '/location/province'],
#  ['/building', '/location/bridge', '/location'],
#  ['/location/city', '/location'],
#  ['/organization/sports_league', '/organization'],
#  ['/location'],
#  ['/geography/island', '/location/country', '/geography', '/location'],
#  ['/living_thing'],
#  ['/person/author', '/person'],
#  ['/person'],
#  ['/government',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government/government',
#   '/government_agency',
#   '/park'],
#  ['/people/ethnicity', '/people'],
#  ['/news_agency', '/location/city', '/location'],
#  ['/organization', '/organization/company'],
#  ['/location/city', '/location'],
#  ['/location/cemetery', '/location', '/location/province'],
#  ['/person'],
#  ['/government',
#   '/location/city',
#   '/location',
#   '/government/government',
#   '/location/province'],
#  ['/location/city', '/location'],
#  ['/person/athlete', '/person/actor', '/person'],
#  ['/organization', '/government', '/government/political_party'],
#  ['/person/author',
#   '/person/actor',
#   '/person/artist',
#   '/person/director',
#   '/person'],
#  ['/organization'],
#  ['/geography/island', '/geography', '/location'],
#  ['/geography/island', '/geography', '/location'],
#  ['/organization', '/organization/company'],
#  ['/location/city', '/location'],
#  ['/person/actor', '/person/artist', '/person/musician', '/person'],
#  ['/education', '/education/educational_degree'],
#  ['/event', '/event/military_conflict', '/event/attack'],
#  ['/music'],
#  ['/people/ethnicity',
#   '/people',
#   '/government',
#   '/location/country',
#   '/location',
#   '/government/government'],
#  ['/location'],
#  ['/chemistry'],
#  ['/person/author', '/person'],
#  ['/disease'],
#  ['/location'],
#  ['/location/country', '/location'],
#  ['/government', '/government/government'],
#  ['/people/ethnicity', '/people', '/location/country', '/location'],
#  ['/person/artist', '/person/musician', '/person'],
#  ['/building', '/location', '/building/airport'],
#  ['/person/artist', '/person'],
#  ['/building', '/location/cemetery', '/location'],
#  ['/person'],
#  ['/art/film', '/art'],
#  ['/person/actor', '/person'],
#  ['/building', '/location', '/building/sports_facility'],
#  ['/people/ethnicity', '/people'],
#  ['/location/city', '/location'],
#  ['/organization', '/organization/company'],
#  ['/location/city', '/location'],
#  ['/government',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government/government',
#   '/government_agency',
#   '/park'],
#  ['/organization', '/government', '/government/political_party'],
#  ['/written_work'],
#  ['/person'],
#  ['/location/city', '/location'],
#  ['/organization',
#   '/location/city',
#   '/location/county',
#   '/location',
#   '/language',
#   '/organization/company',
#   '/person'],
#  ['/event', '/event/military_conflict'],
#  ['/organization', '/organization/educational_institution', '/location'],
#  ['/location/city', '/location'],
#  ['/organization/sports_league', '/organization', '/event'],
#  ['/person/author', '/person'],
#  ['/organization', '/organization/sports_team', '/location'],
#  ['/living_thing'],
#  ['/location/city', '/location'],
#  ['/people/ethnicity',
#   '/people',
#   '/person/artist',
#   '/location/country',
#   '/location',
#   '/person'],
#  ['/location/country', '/location'],
#  ['/location'],
#  ['/people/ethnicity', '/people', '/location/country', '/location'],
#  ['/person/politician', '/person'],
#  ['/person/monarch', '/person'],
#  ['/title'],
#  ['/person/actor', '/person/artist', '/person'],
#  ['/organization', '/organization/sports_team'],
#  ['/event'],
#  ['/location/body_of_water', '/location'],
#  ['/location'],
#  ['/location/city', '/location'],
#  ['/title'],
#  ['/event', '/event/military_conflict', '/event/attack'],
#  ['/event/sports_event', '/event'],
#  ['/disease'],
#  ['/location'],
#  ['/people/ethnicity', '/people', '/location/country', '/location'],
#  ['/person/religious_leader', '/person'],
#  ['/location/country', '/location'],
#  ['/building', '/location'],
#  ['/location/city', '/location'],
#  ['/location/cemetery', '/location/city', '/location'],
#  ['/location/body_of_water', '/location'],
#  ['/people/ethnicity', '/people', '/location/country', '/location'],
#  ['/organization', '/organization/company'],
#  ['/location', '/location/province'],
#  ['/organization', '/government_agency'],
#  ['/organization', '/religion', '/religion/religion'],
#  ['/organization', '/organization/company'],
#  ['/broadcast_program'],
#  ['/government', '/location/country', '/location', '/government/government'],
#  ['/organization', '/organization/sports_team'],
#  ['/event/election', '/event'],
#  ['/location/country', '/location'],
#  ['/location/country', '/location'],
#  ['/organization', '/organization/company'],
#  ['/people/ethnicity', '/people', '/location/country', '/location'],
#  ['/person/artist', '/person'],
#  ['/location/cemetery', '/location/city', '/location'],
#  ['/location/city', '/location/country', '/location'],
#  ['/location/city', '/location', '/location/province'],
#  ['/organization', '/organization/sports_team'],
#  ['/location/city', '/location'],
#  ['/location/city', '/location'],
#  ['/organization', '/government', '/government/political_party'],
#  ['/person/author',
#   '/person/actor',
#   '/person/artist',
#   '/person/director',
#   '/person'],
#  ['/location/country', '/location', '/government_agency'],
#  ['/person/actor', '/person'],
#  ['/organization', '/organization/educational_institution', '/location'],
#  ['/location/city', '/location'],
#  ['/person/actor', '/person/artist', '/person'],
#  ['/building', '/location'],
#  ['/location/city', '/location'],
#  ['/organization', '/organization/educational_institution', '/location'],
#  ['/location/city', '/location'],
#  ['/event/election', '/event'],
#  ['/person/author',
#   '/person/actor',
#   '/person/artist',
#   '/person/director',
#   '/person'],
#  ['/location'],
#  ['/location/city', '/location'],
#  ['/location'],
#  ['/organization', '/organization/sports_team'],
#  ['/location/city', '/location/county', '/location'],
#  ['/location/city', '/location', '/language'],
#  ['/location/country', '/location'],
#  ['/organization', '/organization/sports_team'],
#  ['/art/film', '/art'],
#  ['/building', '/location', '/building/airport'],
#  ['/location/city', '/location'],
#  ['/location'],
#  ['/person'],
#  ['/music'],
#  ['/product', '/product/car'],
#  ['/organization', '/government', '/government/political_party'],
#  ['/location/cemetery', '/location/city', '/location'],
#  ['/living_thing'],
#  ['/location/city', '/location'],
#  ['/person/actor', '/person/artist', '/person'],
#  ['/person/artist', '/location/country', '/location', '/person'],
#  ['/organization/sports_league', '/organization', '/event'],
#  ['/location/county', '/location'],
#  ['/person'],
#  ['/law'],
#  ['/person/athlete', '/person/actor', '/person'],
#  ['/building', '/location/cemetery', '/location'],
#  ['/location'],
#  ['/person/religious_leader', '/person/monarch', '/person'],
#  ['/building', '/location', '/building/hotel'],
#  ['/location/county', '/location'],
#  ['/people/ethnicity', '/people'],
#  ['/organization/sports_league', '/organization', '/event'],
#  ['/person/author', '/person/actor', '/person'],
#  ['/location/city', '/location'],
#  ['/person/author',
#   '/person/actor',
#   '/person/artist',
#   '/person/director',
#   '/person'],
#  ['/person/author',
#   '/person/athlete',
#   '/organization',
#   '/person/artist',
#   '/organization/company',
#   '/person'],
#  ['/title'],
#  ['/organization', '/organization/sports_team'],
#  ['/location'],
#  ['/person/artist', '/person/musician', '/person'],
#  ['/person/actor', '/person'],
#  ['/location/body_of_water', '/location'],
#  ['/people/ethnicity', '/people', '/location/country', '/location'],
#  ['/music'],
#  ['/person/author',
#   '/organization',
#   '/person/engineer',
#   '/government_agency',
#   '/person'],
#  ['/music'],
#  ['/person/author', '/organization', '/organization/company', '/person'],
#  ['/person/politician', '/person/monarch', '/person'],
#  ['/location/body_of_water', '/location'],
#  ['/person/artist',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government_agency',
#   '/language',
#   '/title',
#   '/person'],
#  ['/location/country', '/location'],
#  ['/location/city', '/location'],
#  ['/location/city', '/location'],
#  ['/product', '/product/car'],
#  ['/organization', '/organization/sports_team'],
#  ['/organization', '/organization/company'],
#  ['/organization'],
#  ['/person/actor', '/person/artist', '/person/musician', '/person'],
#  ['/location/county', '/location'],
#  ['/organization', '/organization/sports_team'],
#  ['/person'],
#  ['/person/artist', '/person/musician', '/person'],
#  ['/location/city', '/location', '/location/province'],
#  ['/location/cemetery', '/location/city', '/location'],
#  ['/location/country', '/location'],
#  ['/location/country', '/location', '/language'],
#  ['/building', '/organization', '/location', '/building/theater'],
#  ['/organization', '/government', '/government/political_party'],
#  ['/location/body_of_water', '/location'],
#  ['/person'],
#  ['/title'],
#  ['/person/artist', '/location', '/person'],
#  ['/person/actor', '/person/artist', '/person/director', '/person'],
#  ['/organization',
#   '/organization/educational_institution',
#   '/organization/sports_team',
#   '/location'],
#  ['/government',
#   '/location/country',
#   '/location',
#   '/government/government',
#   '/government_agency',
#   '/park'],
#  ['/organization', '/event'],
#  ['/person/author', '/person/politician', '/person'],
#  ['/person/artist',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government_agency',
#   '/language',
#   '/title',
#   '/person'],
#  ['/person/actor', '/person/artist', '/person'],
#  ['/person/politician', '/person'],
#  ['/person/author',
#   '/building',
#   '/organization',
#   '/organization/educational_institution',
#   '/location',
#   '/person'],
#  ['/person/artist', '/person/musician', '/person'],
#  ['/location/city', '/location'],
#  ['/location/city', '/location'],
#  ['/building',
#   '/organization',
#   '/organization/educational_institution',
#   '/location'],
#  ['/person'],
#  ['/military', '/organization'],
#  ['/location/country', '/location'],
#  ['/organization/sports_league', '/organization', '/event'],
#  ['/organization', '/organization/educational_institution'],
#  ['/person/author', '/person/actor', '/person/politician', '/person'],
#  ['/organization', '/organization/company'],
#  ['/organization', '/organization/educational_institution', '/location'],
#  ['/location/city', '/location'],
#  ['/building', '/location', '/building/sports_facility'],
#  ['/location'],
#  ['/person/artist', '/location/country', '/location', '/language', '/person'],
#  ['/person/author', '/person/soldier', '/person'],
#  ['/person/soldier', '/person/actor', '/person/politician', '/person'],
#  ['/building', '/location'],
#  ['/location/city', '/location'],
#  ['/location/country', '/location'],
#  ['/living_thing'],
#  ['/person/politician', '/person'],
#  ['/organization', '/organization/company'],
#  ['/organization', '/organization/educational_institution', '/location'],
#  ['/person/monarch', '/person'],
#  ['/law'],
#  ['/product/instrument', '/product'],
#  ['/person/author', '/government', '/government/government', '/person'],
#  ['/location/city', '/location', '/location/province'],
#  ['/location/city', '/location'],
#  ['/event'],
#  ['/location'],
#  ['/location/city', '/location'],
#  ['/living_thing'],
#  ['/broadcast_network'],
#  ['/location/city', '/location'],
#  ['/location/country', '/location', '/language'],
#  ['/organization/sports_league', '/organization', '/organization/company'],
#  ['/person/athlete', '/person'],
#  ['/event'],
#  ['/person/monarch', '/person'],
#  ['/people/ethnicity', '/people'],
#  ['/person/author', '/person'],
#  ['/event/sports_event', '/event'],
#  ['/location'],
#  ['/written_work'],
#  ['/title'],
#  ['/location', '/location/province'],
#  ['/person/author', '/government', '/government/government', '/person'],
#  ['/person/author', '/person'],
#  ['/medicine/medical_treatment', '/medicine/drug', '/medicine'],
#  ['/event'],
#  ['/person'],
#  ['/person/actor', '/person/artist', '/person'],
#  ['/location/city', '/location'],
#  ['/location/country', '/location'],
#  ['/person/artist', '/location/country', '/location', '/person'],
#  ['/game'],
#  ['/location'],
#  ['/person/athlete', '/person/actor', '/person'],
#  ['/organization',
#   '/person/artist',
#   '/broadcast_network',
#   '/person/director',
#   '/person'],
#  ['/event'],
#  ['/event'],
#  ['/person/author', '/person/religious_leader', '/person'],
#  ['/location/city', '/location/county', '/location'],
#  ['/music'],
#  ['/music'],
#  ['/location/body_of_water', '/location'],
#  ['/organization'],
#  ['/person/athlete', '/person'],
#  ['/building', '/location'],
#  ['/organization', '/organization/educational_institution', '/location'],
#  ['/location/city', '/location'],
#  ['/location'],
#  ['/location/country', '/location', '/person'],
#  ['/location'],
#  ['/product', '/product/ship'],
#  ['/person/actor', '/person'],
#  ['/location/city', '/location'],
#  ['/person/athlete', '/person'],
#  ['/person/author',
#   '/person/actor',
#   '/person/artist',
#   '/person/director',
#   '/person'],
#  ['/people/ethnicity', '/people', '/religion', '/religion/religion'],
#  ['/person'],
#  ['/event', '/event/military_conflict'],
#  ['/people/ethnicity',
#   '/people',
#   '/person/artist',
#   '/location/country',
#   '/location',
#   '/person'],
#  ['/transportation', '/location', '/transportation/road'],
#  ['/language'],
#  ['/government', '/location/country', '/location', '/government/government'],
#  ['/event/natural_disaster', '/event', '/location/country', '/location'],
#  ['/organization', '/organization/educational_institution', '/location'],
#  ['/location'],
#  ['/person/politician', '/person'],
#  ['/geography/island', '/location/country', '/geography', '/location'],
#  ['/government',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government/government',
#   '/government_agency',
#   '/park'],
#  ['/organization',
#   '/organization/educational_institution',
#   '/location',
#   '/organization/company'],
#  ['/person/politician', '/person'],
#  ['/person/politician', '/person/doctor', '/person'],
#  ['/location/city', '/location'],
#  ['/person'],
#  ['/location/city', '/location'],
#  ['/organization', '/organization/airline', '/organization/company'],
#  ['/person'],
#  ['/person/athlete', '/person'],
#  ['/person/politician', '/person'],
#  ['/news_agency',
#   '/written_work',
#   '/person/artist',
#   '/person/director',
#   '/person'],
#  ['/person/artist', '/title', '/person'],
#  ['/organization', '/organization/sports_team'],
#  ['/location/city', '/location'],
#  ['/organization', '/person/engineer', '/organization/company', '/person'],
#  ['/organization/sports_league', '/organization'],
#  ['/title'],
#  ['/person/author', '/person/artist', '/person'],
#  ['/education', '/education/educational_degree'],
#  ['/government',
#   '/location/country',
#   '/location',
#   '/government/government',
#   '/government_agency',
#   '/park'],
#  ['/location/city', '/location'],
#  ['/organization', '/organization/educational_institution', '/location'],
#  ['/person/author',
#   '/news_agency',
#   '/organization',
#   '/person/artist',
#   '/government',
#   '/location',
#   '/government/government',
#   '/person'],
#  ['/person'],
#  ['/location'],
#  ['/location'],
#  ['/organization', '/organization/company'],
#  ['/person/artist',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government_agency',
#   '/language',
#   '/title',
#   '/person'],
#  ['/location/city', '/location'],
#  ['/person/politician', '/person'],
#  ['/person/author', '/person'],
#  ['/person/politician', '/person'],
#  ['/event'],
#  ['/location/city', '/location'],
#  ['/location/county', '/location'],
#  ['/location/city', '/location/county', '/location'],
#  ['/location/country', '/location'],
#  ['/person/actor', '/person/artist', '/person/musician', '/person'],
#  ['/person/artist', '/person'],
#  ['/medicine/medical_treatment', '/medicine/drug', '/medicine'],
#  ['/location'],
#  ['/astral_body'],
#  ['/location/city', '/location'],
#  ['/military', '/event', '/event/military_conflict', '/event/attack'],
#  ['/person'],
#  ['/location/city', '/location'],
#  ['/event/election', '/event'],
#  ['/people/ethnicity', '/people'],
#  ['/organization/sports_league', '/organization'],
#  ['/location/country', '/location'],
#  ['/person/author',
#   '/location/cemetery',
#   '/location',
#   '/location/province',
#   '/person'],
#  ['/location/city', '/location'],
#  ['/person/actor', '/person'],
#  ['/location'],
#  ['/location/country', '/location'],
#  ['/person/athlete', '/person/actor', '/person'],
#  ['/person/author', '/person'],
#  ['/person/artist',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government_agency',
#   '/language',
#   '/title',
#   '/person'],
#  ['/location'],
#  ['/person/athlete',
#   '/person/actor',
#   '/person/artist',
#   '/person/director',
#   '/person'],
#  ['/people/ethnicity',
#   '/people',
#   '/person/artist',
#   '/location/country',
#   '/location',
#   '/person'],
#  ['/building', '/government', '/government/government', '/government_agency'],
#  ['/organization/sports_league', '/organization', '/event'],
#  ['/location/country', '/location'],
#  ['/location/city', '/location'],
#  ['/written_work', '/location/cemetery', '/location/city', '/location'],
#  ['/location', '/location/province'],
#  ['/event/protest', '/event'],
#  ['/written_work', '/location/cemetery', '/location/city', '/location'],
#  ['/location/city', '/location'],
#  ['/government',
#   '/location/city',
#   '/location',
#   '/government/government',
#   '/location/province'],
#  ['/person/author',
#   '/person/actor',
#   '/person/artist',
#   '/person/musician',
#   '/person'],
#  ['/location/city', '/location'],
#  ['/person'],
#  ['/disease'],
#  ['/location'],
#  ['/person'],
#  ['/person/monarch', '/person'],
#  ['/person/actor', '/person/politician', '/person'],
#  ['/person/actor', '/person/artist', '/person'],
#  ['/organization', '/organization/sports_team'],
#  ['/location/county', '/location'],
#  ['/person/artist', '/person/musician', '/person'],
#  ['/location'],
#  ['/organization'],
#  ['/organization', '/organization/sports_team'],
#  ['/organization', '/government', '/government/political_party'],
#  ['/building', '/organization', '/location', '/government_agency'],
#  ['/location/city', '/location'],
#  ['/person/artist',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government_agency',
#   '/language',
#   '/title',
#   '/person'],
#  ['/building'],
#  ['/location/country', '/person/director', '/location', '/person'],
#  ['/geography/island', '/geography', '/location'],
#  ['/location/city', '/location'],
#  ['/location/city', '/location'],
#  ['/title'],
#  ['/location/city', '/location'],
#  ['/music'],
#  ['/person/actor', '/person/artist', '/person'],
#  ['/disease'],
#  ['/person'],
#  ['/person/athlete', '/person'],
#  ['/person'],
#  ['/location'],
#  ['/location/city', '/location'],
#  ['/person/actor', '/person'],
#  ['/geography', '/location', '/geography/mountain'],
#  ['/location/city', '/location'],
#  ['/written_work'],
#  ['/government',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government/government'],
#  ['/religion', '/religion/religion'],
#  ['/person/artist', '/person'],
#  ['/organization', '/government', '/government/political_party'],
#  ['/organization', '/organization/sports_team'],
#  ['/building',
#   '/organization',
#   '/organization/educational_institution',
#   '/location'],
#  ['/government', '/government/government'],
#  ['/person/actor', '/person/artist', '/person'],
#  ['/person/author', '/person/artist', '/person/musician', '/person'],
#  ['/building', '/location'],
#  ['/transportation', '/location', '/transportation/road'],
#  ['/person/author',
#   '/government',
#   '/location/country',
#   '/location',
#   '/government/government',
#   '/language',
#   '/person'],
#  ['/location/city', '/location'],
#  ['/location/city', '/location'],
#  ['/location/county', '/location'],
#  ['/location/city', '/location'],
#  ['/person'],
#  ['/organization', '/organization/company'],
#  ['/art/film', '/play', '/music', '/art'],
#  ['/organization', '/person/engineer', '/organization/company', '/person'],
#  ['/organization', '/organization/educational_institution', '/location'],
#  ['/person'],
#  ['/location/county', '/location'],
#  ['/organization', '/organization/sports_team'],
#  ['/person/coach', '/person'],
#  ['/person/actor', '/person'],
#  ['/written_work'],
#  ['/location'],
#  ['/organization', '/location/cemetery', '/location/city', '/location'],
#  ['/person/artist',
#   '/location/cemetery',
#   '/location/country',
#   '/location',
#   '/government_agency',
#   '/language',
#   '/title',
#   '/person'],
#  ['/person/actor', '/person'],
#  ['/military', '/event', '/event/military_conflict', '/event/attack'],
#  ['/organization', '/organization/company'],
#  ['/law'],
#  ['/location/city', '/location'],
#  ['/person/author',
#   '/person/actor',
#   '/person/artist',
#   '/person/director',
#   '/person'],
#  ['/government', '/location/country', '/location', '/government/government'],
#  ['/person/author',
#   '/organization',
#   '/person/engineer',
#   '/organization/educational_institution',
#   '/organization/company',
#   '/person'],
#  ['/person/author', '/person/actor', '/person/director', '/person'],
#  ['/written_work']]

# %%
def print_result(p1, p2, p3, label):
    for j in range(mini_batch_size):
        print('|{:#^121}|'.format(''))
        base_sentence = '|{:^25}|{:^95}|'
        print(base_sentence.format('sentence_idx', i + j + 1))        
        print(base_sentence.format('true_labels', ','.join(label[j])))
        print(base_sentence.format('base_model', ','.join(p1[j])))
        print(base_sentence.format('ft_model', ','.join(p2[j])))
        print(base_sentence.format('frozen_model', ','.join(p3[j])))
    print('|{:#^121}|'.format(''))

# %%
print_result(base_preds, ft_preds, fro_preds, batch_labels)
# Out:
# |#########################################################################################################################|
# |      sentence_idx       |                                              11                                               |
# |       true_labels       |                                    /person/athlete,/person                                    |
# |       base_model        |                                            /person                                            |
# |        ft_model         |                                    /person/athlete,/person                                    |
# |      frozen_model       |                                            /PERSON                                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                              12                                               |
# |       true_labels       |                    /person/author,/person/artist,/person/musician,/person                     |
# |       base_model        |                           /person/athlete,/location/city,/location                            |
# |        ft_model         |                                           /location                                           |
# |      frozen_model       |                                        /SUBSTANCE/FOOD                                        |
# |#########################################################################################################################|
# |      sentence_idx       |                                              13                                               |
# |       true_labels       |/person/artist,/location/cemetery,/location/country,/location,/government_agency,/language,/title,/person|
# |       base_model        |                                           /location                                           |
# |        ft_model         |                                            /person                                            |
# |      frozen_model       |                            /ORGANIZATION,/ORGANIZATION/CORPORATION                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                              14                                               |
# |       true_labels       |                                        /art/film,/art                                         |
# |       base_model        |                             /person/actor,/person/artist,/person                              |
# |        ft_model         |                                     /person/actor,/person                                     |
# |      frozen_model       |                                            /PERSON                                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                              15                                               |
# |       true_labels       |                                           /location                                           |
# |       base_model        |                                         /organization                                         |
# |        ft_model         |                           /organization,/government/political_party                           |
# |      frozen_model       |                                            /PERSON                                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                              16                                               |
# |       true_labels       |                                     /person/actor,/person                                     |
# |       base_model        |                                  /location/country,/location                                  |
# |        ft_model         |                                           /location                                           |
# |      frozen_model       |                                        /GPE,/LOCATION                                         |
# |#########################################################################################################################|
# |      sentence_idx       |                                              17                                               |
# |       true_labels       |                                           /language                                           |
# |       base_model        |                                   /location/city,/location                                    |
# |        ft_model         |                                           /location                                           |
# |      frozen_model       |                                             /GPE                                              |
# |#########################################################################################################################|
# |      sentence_idx       |                                              18                                               |
# |       true_labels       |                                   /location/city,/location                                    |
# |       base_model        |                                           /location                                           |
# |        ft_model         |                                           /location                                           |
# |      frozen_model       |                                        /GPE/CITY,/GPE                                         |
# |#########################################################################################################################|
# |      sentence_idx       |                                              19                                               |
# |       true_labels       |                                   /location/city,/location                                    |
# |       base_model        |                               /location/body_of_water,/location                               |
# |        ft_model         |                                           /location                                           |
# |      frozen_model       |                                             /GPE                                              |
# |#########################################################################################################################|
# |      sentence_idx       |                                              20                                               |
# |       true_labels       |                            /person/artist,/person/musician,/person                            |
# |       base_model        |         /people/ethnicity,/people,/person/artist,/location/country,/location,/person          |
# |        ft_model         |                                  /location/country,/location                                  |
# |      frozen_model       |                                  /GPE/COUNTRY,/GPE,/LOCATION                                  |
# |#########################################################################################################################|
