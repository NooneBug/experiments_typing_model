# %%
import pickle
from typing_model.models.BERT_models import ConcatenatedContextBERTTyper
from torch.nn import Sigmoid
import torch

# %%
path_to_base_model = 'checkpoints/BF_bbn/model.ckpt'
base_model_aux_path = 'dataloaders/Bert_Baseline_bbn_train_auxiliary_variables.pkl'
base_model_dev_loader_path = 'dataloaders/Bert_Baseline_bbn_dev.pkl'

# %%
path_to_ft_model = 'checkpoints/FT_BBN_into_FIGER-v0.ckpt'
ft_model_aux_path = 'dataloaders/Bert_Baseline_figer_train_auxiliary_variables.pkl'
ft_model_dev_loader_path = 'dataloaders/Bert_Baseline_figer_dev.pkl'

# %%
path_to_frozen_model = 'checkpoints/BBS_bbn-v1.ckpt'
fro_model_aux_path = 'dataloaders/Bert_Baseline_bbn_train_auxiliary_variables.pkl'
fro_model_dev_loader_path = 'dataloaders/Bert_Baseline_bbn_dev.pkl'

# %% [markdown]
# ### Load aux variables

# %%
with open(base_model_aux_path, 'rb') as inp:
    bm_id2label, bm_label2id, bm_class_number = pickle.load(inp)

# %%
with open(ft_model_aux_path, 'rb') as inp:
    ft_id2label, ft_label2id, ft_class_number = pickle.load(inp)

# %%
with open(fro_model_aux_path, 'rb') as inp:
    fro_id2label, fro_label2id, fro_class_number = pickle.load(inp)

# %% [markdown]
# ### Load models & dataloaders

# %%
base_model = ConcatenatedContextBERTTyper.load_from_checkpoint(path_to_base_model,
                                                               id2label = bm_id2label, 
                                                               label2id = bm_label2id, 
                                                               classes = bm_class_number,
                                                              weights = None).cuda()

# %%
ft_model = ConcatenatedContextBERTTyper.load_from_checkpoint(path_to_ft_model,
                                                               id2label = ft_id2label, 
                                                               label2id = ft_label2id, 
                                                               classes = ft_class_number,
                                                              weights = None).cuda()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-85524c5d12bc> in <module>
#       3                                                                label2id = ft_label2id,
#       4                                                                classes = ft_class_number,
# ----> 5                                                               weights = None).cuda()
#
# ~/typing_network/another_env/lib/python3.6/site-packages/pytorch_lightning/core/saving.py in load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#     128             checkpoint = pl_load(checkpoint_path, map_location=map_location)
#     129         else:
# --> 130             checkpoint = pl_load(checkpoint_path, map_location=lambda storage, loc: storage)
#     131
#     132         if hparams_file is not None:
#
# ~/typing_network/another_env/lib/python3.6/site-packages/pytorch_lightning/utilities/cloud_io.py in load(path_or_url, map_location)
#      29         return torch.hub.load_state_dict_from_url(str(path_or_url), map_location=map_location)
#      30     fs = get_filesystem(path_or_url)
# ---> 31     with fs.open(path_or_url, "rb") as f:
#      32         return torch.load(f, map_location=map_location)
#      33
#
# ~/typing_network/another_env/lib/python3.6/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     901                 autocommit=ac,
#     902                 cache_options=cache_options,
# --> 903                 **kwargs
#     904             )
#     905             if not ac:
#
# ~/typing_network/another_env/lib/python3.6/site-packages/fsspec/implementations/local.py in _open(self, path, mode, block_size, **kwargs)
#     113         if self.auto_mkdir and "w" in mode:
#     114             self.makedirs(self._parent(path), exist_ok=True)
# --> 115         return LocalFileOpener(path, mode, fs=self, **kwargs)
#     116
#     117     def touch(self, path, **kwargs):
#
# ~/typing_network/another_env/lib/python3.6/site-packages/fsspec/implementations/local.py in __init__(self, path, mode, autocommit, fs, **kwargs)
#     195         self.autocommit = autocommit
#     196         self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 197         self._open()
#     198
#     199     def _open(self):
#
# ~/typing_network/another_env/lib/python3.6/site-packages/fsspec/implementations/local.py in _open(self)
#     200         if self.f is None or self.f.closed:
#     201             if self.autocommit or "w" not in self.mode:
# --> 202                 self.f = open(self.path, mode=self.mode)
#     203             else:
#     204                 # TODO: check if path is writable?
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/vmanuel/typing_network/typing_experiments/checkpoints/FT_BBN_into_FIGER-v0.ckpt'

# %%
fro_model = ConcatenatedContextBERTTyper.load_from_checkpoint(path_to_frozen_model,
                                                               id2label = fro_id2label, 
                                                               label2id = fro_label2id, 
                                                               classes = fro_class_number,
                                                              weights = None).cuda()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-ce5a4019a681> in <module>
#       3                                                                label2id = fro_label2id,
#       4                                                                classes = fro_class_number,
# ----> 5                                                               weights = None).cuda()
#
# ~/typing_network/another_env/lib/python3.6/site-packages/pytorch_lightning/core/saving.py in load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#     128             checkpoint = pl_load(checkpoint_path, map_location=map_location)
#     129         else:
# --> 130             checkpoint = pl_load(checkpoint_path, map_location=lambda storage, loc: storage)
#     131
#     132         if hparams_file is not None:
#
# ~/typing_network/another_env/lib/python3.6/site-packages/pytorch_lightning/utilities/cloud_io.py in load(path_or_url, map_location)
#      29         return torch.hub.load_state_dict_from_url(str(path_or_url), map_location=map_location)
#      30     fs = get_filesystem(path_or_url)
# ---> 31     with fs.open(path_or_url, "rb") as f:
#      32         return torch.load(f, map_location=map_location)
#      33
#
# ~/typing_network/another_env/lib/python3.6/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     901                 autocommit=ac,
#     902                 cache_options=cache_options,
# --> 903                 **kwargs
#     904             )
#     905             if not ac:
#
# ~/typing_network/another_env/lib/python3.6/site-packages/fsspec/implementations/local.py in _open(self, path, mode, block_size, **kwargs)
#     113         if self.auto_mkdir and "w" in mode:
#     114             self.makedirs(self._parent(path), exist_ok=True)
# --> 115         return LocalFileOpener(path, mode, fs=self, **kwargs)
#     116
#     117     def touch(self, path, **kwargs):
#
# ~/typing_network/another_env/lib/python3.6/site-packages/fsspec/implementations/local.py in __init__(self, path, mode, autocommit, fs, **kwargs)
#     195         self.autocommit = autocommit
#     196         self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 197         self._open()
#     198
#     199     def _open(self):
#
# ~/typing_network/another_env/lib/python3.6/site-packages/fsspec/implementations/local.py in _open(self)
#     200         if self.f is None or self.f.closed:
#     201             if self.autocommit or "w" not in self.mode:
# --> 202                 self.f = open(self.path, mode=self.mode)
#     203             else:
#     204                 # TODO: check if path is writable?
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/vmanuel/typing_network/typing_experiments/checkpoints/BBS_bbn-v1.ckpt'

# %%
with open(base_model_dev_loader_path, 'rb') as inp:
    dataloader = pickle.load(inp)

# %% [markdown]
# ## Generate Predictions

# %%
sig = Sigmoid().cuda()

# %%
mini_batch_size = 10
admit_void_prediction = False

# %%
def get_model_pred(model, id2label, mentions, contexts):
    all_preds = []
    all_labels = []
    avg_predictions = 0
    
    mentions = mentions.cuda()
    contexts = contexts.cuda()
    pred = sig(model(mentions, contexts))

    pred = pred.detach().cpu()

    mask = pred > .5
    batch_preds = []
    for i, m in enumerate(mask):
        ex_preds = []   
        pred_ids =  m.nonzero()

        if len(pred_ids) == 0:
            if admit_void_prediction:
                void_counter += 1
            else:
                pred_ids = [torch.argmax(pred[i])]
        avg_predictions += len(pred_ids)

        for p in pred_ids:
            ex_preds.append(id2label[p.item()])
        batch_preds.append(ex_preds)
    all_preds.extend(batch_preds)
    
    avg_predictions = avg_predictions/mini_batch_size
    return all_preds, avg_predictions

# %%
dt = iter(dataloader)

# %%
mention, context, label = next(dt)

# %%
i = 0

# %%
i += mini_batch_size

# %%
base_preds, base_avg_preds = get_model_pred(base_model, bm_id2label, 
                                             mention[i: i + mini_batch_size], 
                                             context[i: i + mini_batch_size])
# ft_preds, ft_avg_preds = get_model_pred(ft_model, ft_id2label, 
#                                        mention[i: i + mini_batch_size],
#                                        context[i: i + mini_batch_size])
# fro_preds, fro_avg_preds = get_model_pred(fro_model, fro_id2label, 
#                                        mention[i: i + mini_batch_size],
#                                        context[i: i + mini_batch_size])
# Out:
# /home/vmanuel/typing_network/another_env/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   app.launch_new_instance()

# %%
mask = label == 1
batch_labels = []
for m in mask:
    ex_labels = []
    labels_ids = m.nonzero()
    for l in labels_ids:
        ex_labels.append(bm_id2label[l.item()])
    batch_labels.append(ex_labels)
batch_labels
# Out:
# [['/PERSON'],
#  ['/GPE/CITY', '/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/PERSON'],
#  ['/CONTACT_INFO/url', '/CONTACT_INFO'],
#  ['/WORK_OF_ART/BOOK', '/CONTACT_INFO/url', '/CONTACT_INFO', '/WORK_OF_ART'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/CITY', '/GPE'],
#  ['/LAW'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/EVENT'],
#  ['/PRODUCT', '/PRODUCT/VEHICLE'],
#  ['/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/GPE/CITY', '/GPE'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/CONTACT_INFO/url', '/CONTACT_INFO'],
#  ['/LOCATION/REGION', '/LOCATION/CONTINENT', '/LOCATION'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/CITY', '/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/GPE/CITY', '/GPE'],
#  ['/CONTACT_INFO/url', '/CONTACT_INFO'],
#  ['/CONTACT_INFO/url', '/CONTACT_INFO'],
#  ['/SUBSTANCE'],
#  ['/PERSON'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/EVENT'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION/REGION', '/LOCATION'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/PERSON'],
#  ['/WORK_OF_ART/BOOK', '/CONTACT_INFO/url', '/CONTACT_INFO', '/WORK_OF_ART'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/WORK_OF_ART'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/GPE/CITY', '/GPE'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION/REGION', '/LOCATION'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/PERSON'],
#  ['/ORGANIZATION'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/PRODUCT', '/SUBSTANCE/FOOD', '/SUBSTANCE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/CITY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/ORGANIZATION/EDUCATIONAL', '/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/SUBSTANCE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/GPE/CITY', '/GPE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/GPE/CITY', '/GPE'],
#  ['/GPE/CITY', '/GPE'],
#  ['/WORK_OF_ART', '/WORK_OF_ART/SONG'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION/EDUCATIONAL', '/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/PLANT'],
#  ['/PERSON'],
#  ['/GPE/CITY', '/GPE'],
#  ['/WORK_OF_ART/BOOK', '/WORK_OF_ART'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/GPE/CITY', '/GPE'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/WORK_OF_ART/BOOK', '/WORK_OF_ART'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/PERSON'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/PERSON'],
#  ['/WORK_OF_ART/BOOK', '/CONTACT_INFO/url', '/CONTACT_INFO', '/WORK_OF_ART'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/GPE/CITY', '/GPE'],
#  ['/GPE/CITY', '/GPE'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/WORK_OF_ART', '/WORK_OF_ART/SONG'],
#  ['/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/ORGANIZATION/EDUCATIONAL', '/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/WORK_OF_ART/BOOK', '/CONTACT_INFO/url', '/CONTACT_INFO', '/WORK_OF_ART'],
#  ['/PERSON'],
#  ['/CONTACT_INFO/url', '/CONTACT_INFO'],
#  ['/EVENT', '/EVENT/HURRICANE'],
#  ['/PERSON'],
#  ['/LOCATION/REGION', '/LOCATION'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/PERSON'],
#  ['/GPE/CITY', '/GPE'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/CITY', '/GPE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/EVENT'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/EVENT'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/FACILITY',
#   '/ORGANIZATION',
#   '/FACILITY/BUILDING',
#   '/ORGANIZATION/CORPORATION'],
#  ['/EVENT'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/PLANT'],
#  ['/SUBSTANCE'],
#  ['/GAME'],
#  ['/GPE/CITY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION/REGION', '/LOCATION'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/CONTACT_INFO/url', '/CONTACT_INFO'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/LOCATION'],
#  ['/WORK_OF_ART'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/GPE/CITY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/PERSON'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PLANT', '/SUBSTANCE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PLANT'],
#  ['/WORK_OF_ART', '/WORK_OF_ART/SONG'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/DISEASE'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/LOCATION/REGION', '/LOCATION/CONTINENT', '/LOCATION'],
#  ['/PERSON'],
#  ['/PRODUCT', '/PRODUCT/VEHICLE'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/LANGUAGE'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/EVENT'],
#  ['/PLANT'],
#  ['/GPE/CITY',
#   '/GPE',
#   '/ORGANIZATION',
#   '/LOCATION',
#   '/ORGANIZATION/CORPORATION'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION', '/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/WORK_OF_ART/BOOK', '/WORK_OF_ART'],
#  ['/CONTACT_INFO/url', '/CONTACT_INFO'],
#  ['/PERSON'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/PLANT'],
#  ['/PERSON'],
#  ['/WORK_OF_ART'],
#  ['/PLANT'],
#  ['/WORK_OF_ART/BOOK', '/WORK_OF_ART'],
#  ['/FACILITY', '/FACILITY/ATTRACTION'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/SUBSTANCE'],
#  ['/DISEASE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/SUBSTANCE/DRUG', '/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/PERSON'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/PERSON'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/PERSON'],
#  ['/GPE/CITY', '/GPE'],
#  ['/PERSON'],
#  ['/LAW'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/CITY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/ORGANIZATION/MUSEUM',
#   '/FACILITY',
#   '/ORGANIZATION',
#   '/FACILITY/ATTRACTION',
#   '/FACILITY/BUILDING'],
#  ['/DISEASE'],
#  ['/GPE/CITY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/EVENT'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/DISEASE'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/PRODUCT', '/PRODUCT/VEHICLE'],
#  ['/EVENT'],
#  ['/GPE/CITY', '/GPE'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/ORGANIZATION'],
#  ['/EVENT'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/PERSON'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/PERSON'],
#  ['/EVENT'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/EVENT'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/EVENT'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/CONTACT_INFO/url', '/CONTACT_INFO'],
#  ['/DISEASE'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/PERSON'],
#  ['/DISEASE'],
#  ['/ORGANIZATION/POLITICAL', '/ORGANIZATION'],
#  ['/DISEASE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/LOCATION/REGION', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/FACILITY', '/FACILITY/ATTRACTION'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/WORK_OF_ART'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/PERSON'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/PLANT'],
#  ['/ORGANIZATION',
#   '/ORGANIZATION/GOVERNMENT',
#   '/ORGANIZATION/CORPORATION',
#   '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/PERSON'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/PERSON'],
#  ['/EVENT'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/GPE/CITY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/WORK_OF_ART', '/WORK_OF_ART/SONG'],
#  ['/FACILITY/AIRPORT', '/FACILITY'],
#  ['/EVENT', '/ORGANIZATION/POLITICAL', '/ORGANIZATION'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/GPE/CITY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/DISEASE'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/PERSON'],
#  ['/DISEASE'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/PRODUCT', '/PRODUCT/VEHICLE'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/ORGANIZATION', '/PERSON'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/ORGANIZATION', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION/EDUCATIONAL', '/ORGANIZATION'],
#  ['/GAME'],
#  ['/WORK_OF_ART'],
#  ['/PLANT'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/WORK_OF_ART/BOOK', '/WORK_OF_ART'],
#  ['/WORK_OF_ART'],
#  ['/GPE/CITY', '/GPE'],
#  ['/WORK_OF_ART', '/WORK_OF_ART/SONG'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/EVENT', '/EVENT/HURRICANE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/WORK_OF_ART'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/DISEASE'],
#  ['/WORK_OF_ART'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/ORGANIZATION/EDUCATIONAL',
#   '/ORGANIZATION',
#   '/ORGANIZATION/CORPORATION',
#   '/PERSON'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/SUBSTANCE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/ANIMAL', '/PLANT'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/PERSON'],
#  ['/SUBSTANCE/CHEMICAL', '/SUBSTANCE'],
#  ['/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/GPE/CITY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT', '/PERSON'],
#  ['/PRODUCT', '/SUBSTANCE/FOOD', '/SUBSTANCE'],
#  ['/PERSON'],
#  ['/ORGANIZATION'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/LANGUAGE'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/GPE', '/GPE/STATE_PROVINCE', '/LOCATION'],
#  ['/GPE/CITY', '/GPE'],
#  ['/GPE/CITY', '/GPE', '/LOCATION'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/ANIMAL', '/PLANT'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/SUBSTANCE/FOOD', '/SUBSTANCE'],
#  ['/GPE/CITY', '/GPE', '/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/PERSON'],
#  ['/WORK_OF_ART/BOOK',
#   '/ORGANIZATION',
#   '/WORK_OF_ART',
#   '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/GPE/COUNTRY', '/GPE'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/PERSON'],
#  ['/GPE/CITY', '/GPE'],
#  ['/GPE/COUNTRY', '/GPE', '/LOCATION'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PLANT'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION', '/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/GPE/CITY', '/GPE'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/EVENT', '/EVENT/WAR'],
#  ['/ORGANIZATION', '/ORGANIZATION/GOVERNMENT'],
#  ['/PERSON'],
#  ['/ORGANIZATION', '/ORGANIZATION/CORPORATION'],
#  ['/PERSON'],
#  ['/DISEASE']]

# %%
def print_result(p1, p2, p3, label):
    for j in range(mini_batch_size):
        print('|{:#^121}|'.format(''))
        base_sentence = '|{:^25}|{:^95}|'
        print(base_sentence.format('sentence_idx', i + j + 1))        
        print(base_sentence.format('true_labels', ','.join(label[j])))
        print(base_sentence.format('base_model', ','.join(p1[j])))
        print(base_sentence.format('ft_model', ','.join(p2[j])))
        print(base_sentence.format('frozen_model', ','.join(p3[j])))
    print('|{:#^121}|'.format(''))

# %%
print_result(base_preds, base_preds, base_preds, batch_labels)
# Out:
# |#########################################################################################################################|
# |      sentence_idx       |                                               1                                               |
# |       true_labels       |                                            /PERSON                                            |
# |       base_model        |                                            /PERSON                                            |
# |        ft_model         |                                            /PERSON                                            |
# |      frozen_model       |                                            /PERSON                                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                               2                                               |
# |       true_labels       |                             /GPE/CITY,/GPE/COUNTRY,/GPE,/LOCATION                             |
# |       base_model        |                             /GPE/CITY,/GPE/COUNTRY,/GPE,/LOCATION                             |
# |        ft_model         |                             /GPE/CITY,/GPE/COUNTRY,/GPE,/LOCATION                             |
# |      frozen_model       |                             /GPE/CITY,/GPE/COUNTRY,/GPE,/LOCATION                             |
# |#########################################################################################################################|
# |      sentence_idx       |                                               3                                               |
# |       true_labels       |                            /ORGANIZATION,/ORGANIZATION/CORPORATION                            |
# |       base_model        |                            /ORGANIZATION,/ORGANIZATION/CORPORATION                            |
# |        ft_model         |                            /ORGANIZATION,/ORGANIZATION/CORPORATION                            |
# |      frozen_model       |                            /ORGANIZATION,/ORGANIZATION/CORPORATION                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                               4                                               |
# |       true_labels       |            /WORK_OF_ART/BOOK,/ORGANIZATION,/WORK_OF_ART,/ORGANIZATION/CORPORATION             |
# |       base_model        |                                            /PERSON                                            |
# |        ft_model         |                                            /PERSON                                            |
# |      frozen_model       |                                            /PERSON                                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                               5                                               |
# |       true_labels       |                                            /PERSON                                            |
# |       base_model        |                                            /PERSON                                            |
# |        ft_model         |                                            /PERSON                                            |
# |      frozen_model       |                                            /PERSON                                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                               6                                               |
# |       true_labels       |                                            /PERSON                                            |
# |       base_model        |                                            /PERSON                                            |
# |        ft_model         |                                            /PERSON                                            |
# |      frozen_model       |                                            /PERSON                                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                               7                                               |
# |       true_labels       |                                       /EVENT,/EVENT/WAR                                       |
# |       base_model        |                                       /EVENT,/EVENT/WAR                                       |
# |        ft_model         |                                       /EVENT,/EVENT/WAR                                       |
# |      frozen_model       |                                       /EVENT,/EVENT/WAR                                       |
# |#########################################################################################################################|
# |      sentence_idx       |                                               8                                               |
# |       true_labels       |                                            /PERSON                                            |
# |       base_model        |                                            /PERSON                                            |
# |        ft_model         |                                            /PERSON                                            |
# |      frozen_model       |                                            /PERSON                                            |
# |#########################################################################################################################|
# |      sentence_idx       |                                               9                                               |
# |       true_labels       |                                /CONTACT_INFO/url,/CONTACT_INFO                                |
# |       base_model        |                                /CONTACT_INFO/url,/CONTACT_INFO                                |
# |        ft_model         |                                /CONTACT_INFO/url,/CONTACT_INFO                                |
# |      frozen_model       |                                /CONTACT_INFO/url,/CONTACT_INFO                                |
# |#########################################################################################################################|
# |      sentence_idx       |                                              10                                               |
# |       true_labels       |                /WORK_OF_ART/BOOK,/CONTACT_INFO/url,/CONTACT_INFO,/WORK_OF_ART                 |
# |       base_model        |                /WORK_OF_ART/BOOK,/CONTACT_INFO/url,/CONTACT_INFO,/WORK_OF_ART                 |
# |        ft_model         |                /WORK_OF_ART/BOOK,/CONTACT_INFO/url,/CONTACT_INFO,/WORK_OF_ART                 |
# |      frozen_model       |                /WORK_OF_ART/BOOK,/CONTACT_INFO/url,/CONTACT_INFO,/WORK_OF_ART                 |
# |#########################################################################################################################|
